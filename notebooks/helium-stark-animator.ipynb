# %%
from heliumstarkanimate import HeliumStarkAnimator
from hsz import HamiltonianMatrix
import numpy as np
# %matplotlib inline
# Out:
# /Users/alexmorgan/anaconda/lib/python3.6/importlib/_bootstrap.py:205: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /Users/alexmorgan/anaconda/lib/python3.6/importlib/_bootstrap.py:205: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
n_min = 5
n_max = 6
S = 1
ham = HamiltonianMatrix(n_min=n_min, n_max=n_max, S=S)
animator = HeliumStarkAnimator(ham)

# %%
state_idx = n_min**2
Efield = np.linspace(0.0, 6.0*10**5, 11) # V/cm
Bfield = 0.01
charge_dists = animator.charge_distribution(state_idx, Efield*1e2, Bfield=Bfield)
# Out:
# Calculating zeeman terms: 100%|██████████| 61/61 [00:00<00:00, 9645.71it/s]
# Calculating stark terms: 100%|██████████| 61/61 [00:01<00:00, 35.22it/s]
# Diagonalise Hamiltonian: 100%|██████████| 11/11 [00:00<00:00, 610.87it/s]
# Computing charge distributions: 100%|██████████| 11/11 [00:03<00:00,  2.67it/s]

# %%
animator.plot(charge_dists[0])

# %%
animator.save(charge_dists)
